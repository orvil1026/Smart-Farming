# %% [markdown]
# Importing Libraries

# %%
#import keras as ke
import tensorflow as tf
import sys


import json
import math
import keras
import keras.backend as K



import numpy as np
import pickle
import cv2
import pandas as pd
import os
from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization


from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from keras import layers, optimizers
from keras.applications import MobileNetV2
from keras.callbacks import ModelCheckpoint
from sklearn.model_selection import train_test_split
from keras.models import Sequential, load_model
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout
from keras.losses import categorical_crossentropy
#from keras.optimizers import adam, sgd

from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint


from keras.models import Model
from keras.optimizers import Adam
from keras.layers import GlobalAveragePooling2D

from keras.applications.inception_v3 import InceptionV3
from keras.utils.np_utils import to_categorical

# %% [raw]
# Printing Versions of keras and tensorflow

# %%
print(tf.__version__) 
print(keras.__version__)
# Out:
# 2.4.1
# 2.4.3

# %%
EPOCHS = 50
INIT_LR = 1e-3
BS = 42
#default_image_size = tuple((256, 256))

default_image_size = tuple((224, 224))

image_size = 0
directory_root = '../input/plantdisease/plantvillage/'
width=224
height=224
depth=3

# %% [markdown]
# **Converting Image Into the Array**

# %%
# function to convert images to array
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size) 
          #  gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %% [markdown]
# *Fetching the images in directory*

# %%
#Fetch images in the directory

image_list, label_list = [], []

try:
    print("[INFO] Loading images ...")
    root_dir = listdir(directory_root)
    for directory in root_dir :
        # remove .DS_Store from list
        if directory == ".DS_Store" :
            root_dir.remove(directory)


    for plant_folder in root_dir :
        plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")
        copy=listdir(f"{directory_root}/{plant_folder}")
        plant_list = []
        print(plant_disease_folder_list)
        for disease_folder in copy :
            # remove .DS_Store from list
            print(disease_folder)
            if disease_folder == ".DS_Store" :
                plant_disease_folder_list.remove(disease_folder)
        for plant_disease_folder in plant_disease_folder_list:
            
            if plant_disease_folder in ["Tomato_Bacterial_spot","Tomato_Early_blight","Tomato_Late_blight","Tomato_Spider_mites_Two_spotted_spider_mite","omato__Tomato_YellowLeaf__Curl_Virus","Tomato__Tomato_mosaic_virus","Tomato_healthy"]:
            
                print(f"[INFO] Processing {plant_disease_folder} ...")
                plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}/")

                for single_plant_disease_image in plant_disease_image_list :
                    if single_plant_disease_image == ".DS_Store" :
                        plant_disease_image_list.remove(single_plant_disease_image)

                for image in plant_disease_image_list[:350]:
                    image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                    if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                        image_list.append(convert_image_to_array(image_directory))
                        label_list.append(plant_disease_folder)
    print("[INFO] Image loading completed")  
except Exception as e:
    print(f"Error : {e}")
# Out:
# [INFO] Loading images ...
# ['Pepper__bell___Bacterial_spot', 'Potato___healthy', 'Tomato_Leaf_Mold', 'Tomato__Tomato_YellowLeaf__Curl_Virus', 'Tomato_Bacterial_spot', 'Tomato_Septoria_leaf_spot', 'Tomato_healthy', 'Tomato_Spider_mites_Two_spotted_spider_mite', 'Tomato_Early_blight', 'Tomato__Target_Spot', 'Pepper__bell___healthy', 'Potato___Late_blight', 'Tomato_Late_blight', 'Potato___Early_blight', 'Tomato__Tomato_mosaic_virus']
# Pepper__bell___Bacterial_spot
# Potato___healthy
# Tomato_Leaf_Mold
# Tomato__Tomato_YellowLeaf__Curl_Virus
# Tomato_Bacterial_spot
# Tomato_Septoria_leaf_spot
# Tomato_healthy
# Tomato_Spider_mites_Two_spotted_spider_mite
# Tomato_Early_blight
# Tomato__Target_Spot
# Pepper__bell___healthy
# Potato___Late_blight
# Tomato_Late_blight
# Potato___Early_blight
# Tomato__Tomato_mosaic_virus
# [INFO] Processing Tomato_Bacterial_spot ...
# [INFO] Processing Tomato_healthy ...
# [INFO] Processing Tomato_Spider_mites_Two_spotted_spider_mite ...
# [INFO] Processing Tomato_Early_blight ...
# [INFO] Processing Tomato_Late_blight ...
# [INFO] Processing Tomato__Tomato_mosaic_virus ...
# [INFO] Image loading completed

# %%
#get size of the processed images
image_size = len(image_list)
print(image_size)
print(len(label_list))
# Out:
# 2100
# 2100

# %%
image_list[0].shape
# Out:
# (224, 224, 3)

# %% [markdown]
# Transform Image Labels using Scikit Learn's LabelBinarizer

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
pickle.dump(label_binarizer,open('label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

# %% [markdown]
# **Print the number of classes**

# %%
print(n_classes)
# Out:
# 6

# %% [markdown]
# *Print the classes*

# %%
print(label_binarizer.classes_)
# Out:
# ['Tomato_Bacterial_spot' 'Tomato_Early_blight' 'Tomato_Late_blight'
#  'Tomato_Spider_mites_Two_spotted_spider_mite'
#  'Tomato__Tomato_mosaic_virus' 'Tomato_healthy']

# %%
print(np.array(image_list[0]).dtype)
# Out:
# float32

# %%
image_list = np.array(image_list, dtype=np.float32)

# %%
print("[INFO] Spliting data to train, test")
x_train, x_test, y_train, y_test = train_test_split(image_list, image_labels, test_size=0.2, random_state = 42) 
#changed random state from 10 to 24
# Out:
# [INFO] Spliting data to train, test

# %%
aug = ImageDataGenerator(
            rotation_range=25, width_shift_range=0.1,
          height_shift_range=0.1, shear_range=0.2, 
    zoom_range=0.2,horizontal_flip=True, 
    fill_mode="nearest")

# %% [markdown]
# **Convolutional Neural Network**

# %% [markdown]
# ![](https://miro.medium.com/max/875/1*XbuW8WuRrAY5pC4t-9DZAQ.jpeg)

# %%
from keras.applications import ResNet50

resnet = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

for layer in resnet.layers[:-4]:
    layer.trainable = False

def nvidia_model():
    model = Sequential()
    model.add(resnet)

    #comment out
   # model.add(MaxPooling2D(pool_size=(2, 2)))
   # model.add(Dropout(0.5))
    
    model.add(Flatten())
    
  
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
  
      
    
    model.add(Dense(6,activation='softmax'))
    optimizer = Adam(lr=1e-3)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    
    return model

model = nvidia_model()
print(model.summary())
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 7, 7, 2048)        23587712
# _________________________________________________________________
# flatten (Flatten)            (None, 100352)            0
# _________________________________________________________________
# dense (Dense)                (None, 512)               51380736
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 3078
# =================================================================
# Total params: 74,971,526
# Trainable params: 52,438,534
# Non-trainable params: 22,532,992
# _________________________________________________________________
# None

# %%
checkpoint = ModelCheckpoint('model.h5', monitor='val_loss',verbose=1,save_best_only=True, mode='auto')

history = model.fit_generator(
    aug.flow(x_train, y_train, batch_size=BS),
    validation_data=(x_test, y_test),
    steps_per_epoch=len(x_train) // BS,
    epochs=40, verbose=1,
    callbacks=[checkpoint]
    )
# Out:
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/40
# 40/40 [==============================] - 24s 462ms/step - loss: 21.7433 - accuracy: 0.5284 - val_loss: 2.8355 - val_accuracy: 0.7167
#
# Epoch 00001: val_loss improved from inf to 2.83553, saving model to model.h5
# Epoch 2/40
# 40/40 [==============================] - 17s 432ms/step - loss: 1.0332 - accuracy: 0.8700 - val_loss: 0.5441 - val_accuracy: 0.8833
#
# Epoch 00002: val_loss improved from 2.83553 to 0.54415, saving model to model.h5
# Epoch 3/40
# 40/40 [==============================] - 18s 439ms/step - loss: 0.2178 - accuracy: 0.9358 - val_loss: 0.1967 - val_accuracy: 0.9333
#
# Epoch 00003: val_loss improved from 0.54415 to 0.19666, saving model to model.h5
# Epoch 4/40
# 40/40 [==============================] - 17s 422ms/step - loss: 0.1858 - accuracy: 0.9391 - val_loss: 0.1494 - val_accuracy: 0.9476
#
# Epoch 00004: val_loss improved from 0.19666 to 0.14936, saving model to model.h5
# Epoch 5/40
# 40/40 [==============================] - 18s 454ms/step - loss: 0.1128 - accuracy: 0.9655 - val_loss: 0.2264 - val_accuracy: 0.9405
#
# Epoch 00005: val_loss did not improve from 0.14936
# Epoch 6/40
# 40/40 [==============================] - 17s 427ms/step - loss: 0.1250 - accuracy: 0.9572 - val_loss: 0.2081 - val_accuracy: 0.9405
#
# Epoch 00006: val_loss did not improve from 0.14936
# Epoch 7/40
# 40/40 [==============================] - 17s 426ms/step - loss: 0.1007 - accuracy: 0.9616 - val_loss: 0.2089 - val_accuracy: 0.9357
#
# Epoch 00007: val_loss did not improve from 0.14936
# Epoch 8/40
# 40/40 [==============================] - 18s 440ms/step - loss: 0.1207 - accuracy: 0.9624 - val_loss: 0.2706 - val_accuracy: 0.9310
#
# Epoch 00008: val_loss did not improve from 0.14936
# Epoch 9/40
# 40/40 [==============================] - 17s 417ms/step - loss: 0.0918 - accuracy: 0.9695 - val_loss: 0.1613 - val_accuracy: 0.9548
#
# Epoch 00009: val_loss did not improve from 0.14936
# Epoch 10/40
# 40/40 [==============================] - 18s 442ms/step - loss: 0.1015 - accuracy: 0.9696 - val_loss: 0.2271 - val_accuracy: 0.9405
#
# Epoch 00010: val_loss did not improve from 0.14936
# Epoch 11/40
# 40/40 [==============================] - 17s 415ms/step - loss: 0.1141 - accuracy: 0.9675 - val_loss: 0.3275 - val_accuracy: 0.9262
#
# Epoch 00011: val_loss did not improve from 0.14936
# Epoch 12/40
# 40/40 [==============================] - 18s 440ms/step - loss: 0.1140 - accuracy: 0.9644 - val_loss: 0.1961 - val_accuracy: 0.9548
#
# Epoch 00012: val_loss did not improve from 0.14936
# Epoch 13/40
# 40/40 [==============================] - 17s 414ms/step - loss: 0.0858 - accuracy: 0.9741 - val_loss: 0.1736 - val_accuracy: 0.9500
#
# Epoch 00013: val_loss did not improve from 0.14936
# Epoch 14/40
# 40/40 [==============================] - 18s 441ms/step - loss: 0.0614 - accuracy: 0.9791 - val_loss: 0.2338 - val_accuracy: 0.9286
#
# Epoch 00014: val_loss did not improve from 0.14936
# Epoch 15/40
# 40/40 [==============================] - 17s 417ms/step - loss: 0.0819 - accuracy: 0.9710 - val_loss: 0.2508 - val_accuracy: 0.9357
#
# Epoch 00015: val_loss did not improve from 0.14936
# Epoch 16/40
# 40/40 [==============================] - 18s 439ms/step - loss: 0.0963 - accuracy: 0.9683 - val_loss: 0.1997 - val_accuracy: 0.9476
#
# Epoch 00016: val_loss did not improve from 0.14936
# Epoch 17/40
# 40/40 [==============================] - 17s 429ms/step - loss: 0.0703 - accuracy: 0.9833 - val_loss: 0.2935 - val_accuracy: 0.9429
#
# Epoch 00017: val_loss did not improve from 0.14936
# Epoch 18/40
# 40/40 [==============================] - 17s 432ms/step - loss: 0.1013 - accuracy: 0.9740 - val_loss: 0.3551 - val_accuracy: 0.9405
#
# Epoch 00018: val_loss did not improve from 0.14936
# Epoch 19/40
# 40/40 [==============================] - 18s 443ms/step - loss: 0.1083 - accuracy: 0.9709 - val_loss: 0.4929 - val_accuracy: 0.9048
#
# Epoch 00019: val_loss did not improve from 0.14936
# Epoch 20/40
# 40/40 [==============================] - 17s 415ms/step - loss: 0.1414 - accuracy: 0.9662 - val_loss: 0.2553 - val_accuracy: 0.9452
#
# Epoch 00020: val_loss did not improve from 0.14936
# Epoch 21/40
# 40/40 [==============================] - 18s 443ms/step - loss: 0.1429 - accuracy: 0.9675 - val_loss: 0.6536 - val_accuracy: 0.8810
#
# Epoch 00021: val_loss did not improve from 0.14936
# Epoch 22/40
# 40/40 [==============================] - 17s 415ms/step - loss: 0.1163 - accuracy: 0.9626 - val_loss: 0.3136 - val_accuracy: 0.9500
#
# Epoch 00022: val_loss did not improve from 0.14936
# Epoch 23/40
# 40/40 [==============================] - 18s 441ms/step - loss: 0.1402 - accuracy: 0.9702 - val_loss: 0.0980 - val_accuracy: 0.9571
#
# Epoch 00023: val_loss improved from 0.14936 to 0.09796, saving model to model.h5
# Epoch 24/40
# 40/40 [==============================] - 17s 435ms/step - loss: 0.0715 - accuracy: 0.9765 - val_loss: 0.1995 - val_accuracy: 0.9452
#
# Epoch 00024: val_loss did not improve from 0.09796
# Epoch 25/40
# 40/40 [==============================] - 17s 425ms/step - loss: 0.0630 - accuracy: 0.9796 - val_loss: 0.1426 - val_accuracy: 0.9548
#
# Epoch 00025: val_loss did not improve from 0.09796
# Epoch 26/40
# 40/40 [==============================] - 17s 429ms/step - loss: 0.0476 - accuracy: 0.9846 - val_loss: 0.1001 - val_accuracy: 0.9738
#
# Epoch 00026: val_loss did not improve from 0.09796
# Epoch 27/40
# 40/40 [==============================] - 17s 423ms/step - loss: 0.0394 - accuracy: 0.9858 - val_loss: 0.1190 - val_accuracy: 0.9643
#
# Epoch 00027: val_loss did not improve from 0.09796
# Epoch 28/40
# 40/40 [==============================] - 17s 416ms/step - loss: 0.0500 - accuracy: 0.9827 - val_loss: 0.1879 - val_accuracy: 0.9571
#
# Epoch 00028: val_loss did not improve from 0.09796
# Epoch 29/40
# 40/40 [==============================] - 17s 421ms/step - loss: 0.0412 - accuracy: 0.9869 - val_loss: 0.1322 - val_accuracy: 0.9619
#
# Epoch 00029: val_loss did not improve from 0.09796
# Epoch 30/40
# 40/40 [==============================] - 17s 412ms/step - loss: 0.0347 - accuracy: 0.9858 - val_loss: 0.1181 - val_accuracy: 0.9786
#
# Epoch 00030: val_loss did not improve from 0.09796
# Epoch 31/40
# 40/40 [==============================] - 17s 429ms/step - loss: 0.0281 - accuracy: 0.9885 - val_loss: 0.1666 - val_accuracy: 0.9476
#
# Epoch 00031: val_loss did not improve from 0.09796
# Epoch 32/40
# 40/40 [==============================] - 17s 423ms/step - loss: 0.0253 - accuracy: 0.9906 - val_loss: 0.1579 - val_accuracy: 0.9667
#
# Epoch 00032: val_loss did not improve from 0.09796
# Epoch 33/40
# 40/40 [==============================] - 17s 423ms/step - loss: 0.0436 - accuracy: 0.9837 - val_loss: 0.3086 - val_accuracy: 0.9476
#
# Epoch 00033: val_loss did not improve from 0.09796
# Epoch 34/40
# 40/40 [==============================] - 17s 417ms/step - loss: 0.1022 - accuracy: 0.9719 - val_loss: 0.1675 - val_accuracy: 0.9690
#
# Epoch 00034: val_loss did not improve from 0.09796
# Epoch 35/40
# 40/40 [==============================] - 17s 421ms/step - loss: 0.0559 - accuracy: 0.9849 - val_loss: 0.0829 - val_accuracy: 0.9690
#
# Epoch 00035: val_loss improved from 0.09796 to 0.08291, saving model to model.h5
# Epoch 36/40
# 40/40 [==============================] - 17s 424ms/step - loss: 0.0374 - accuracy: 0.9845 - val_loss: 0.0992 - val_accuracy: 0.9714
#
# Epoch 00036: val_loss did not improve from 0.08291
# Epoch 37/40
# 40/40 [==============================] - 17s 411ms/step - loss: 0.0364 - accuracy: 0.9866 - val_loss: 0.1947 - val_accuracy: 0.9571
#
# Epoch 00037: val_loss did not improve from 0.08291
# Epoch 38/40
# 40/40 [==============================] - 17s 421ms/step - loss: 0.0664 - accuracy: 0.9834 - val_loss: 0.4754 - val_accuracy: 0.9381
#
# Epoch 00038: val_loss did not improve from 0.08291
# Epoch 39/40
# 40/40 [==============================] - 17s 414ms/step - loss: 0.1433 - accuracy: 0.9703 - val_loss: 0.3093 - val_accuracy: 0.9571
#
# Epoch 00039: val_loss did not improve from 0.08291
# Epoch 40/40
# 40/40 [==============================] - 17s 436ms/step - loss: 0.1128 - accuracy: 0.9760 - val_loss: 0.6185 - val_accuracy: 0.8857
#
# Epoch 00040: val_loss did not improve from 0.08291

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)
#Train and validation accuracy
plt.plot(epochs, acc, 'b', label='Training accurarcy')
plt.plot(epochs, val_acc, 'r', label='Validation accurarcy')
plt.title('Training and Validation accurarcy')
plt.legend()

plt.figure()
#Train and validation lossvv
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and Validation loss')
plt.legend()
plt.show()

# %% [markdown]
# Model Accuracy

# %%
print("[INFO] Calculating model accuracy")
scores = model.evaluate(x_test, y_test)

print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 14/14 [==============================] - 1s 57ms/step - loss: 0.6185 - accuracy: 0.8857
# Test Accuracy: 88.57142925262451

# %%
from sklearn.metrics import classification_report

pred = model.predict(x_test, batch_size=32, verbose=1)
predicted = np.argmax(pred, axis=1)
report = classification_report(np.argmax(y_test, axis=1), predicted)
print(report)
# Out:
# 14/14 [==============================] - 2s 56ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      0.71      0.83        72
#            1       0.78      0.82      0.80        71
#            2       0.85      0.99      0.92        71
#            3       1.00      0.80      0.89        60
#            4       0.96      0.98      0.97        66
#            5       0.82      1.00      0.90        80
#
#     accuracy                           0.89       420
#    macro avg       0.90      0.88      0.88       420
# weighted avg       0.90      0.89      0.88       420

# %%
from keras.models import load_model
model = load_model('model.h5')

# %%
def predict_disease(image_path):
    image_array = convert_image_to_array(image_path)
    np_image = np.array(image_array, dtype=np.float32)
    print(np_image.dtype)
    np_image = np.expand_dims(np_image,0)
    print(np_image.shape)
    plt.imshow(plt.imread(image_path))
    result = model.predict_classes(np_image) 
    print(result)
    print((label_binarizer.classes_[result]))

# %%
predict_disease("../input/plantdisease/PlantVillage/Tomato_Early_blight/00c5c908-fc25-4710-a109-db143da23112___RS_Erly.B 7778.JPG")
# Out:
# float32
# (1, 224, 224, 3)
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# [1]
# ['Tomato_Early_blight']

# %%
image="../input/plantdisease/PlantVillage/Tomato__Tomato_mosaic_virus/0dae2780-43e7-40ac-ae45-95e5318c8f32___PSU_CG 2290.JPG"

# %%
predict_disease(image)
# Out:
# float32
# (1, 224, 224, 3)
# [4]
# ['Tomato__Tomato_mosaic_virus']

# %%
predict_disease("../input/plantdisease/PlantVillage/Potato___Early_blight/001187a0-57ab-4329-baff-e7246a9edeb0___RS_Early.B 8178.JPG")
# Out:
# float32
# (1, 224, 224, 3)
# [1]
# ['Tomato_Early_blight']

# %%
predict_disease("../input/plantdisease/PlantVillage/Tomato_Leaf_Mold/02a29ab9-8cba-47a0-bc2f-e7af7dbae149___Crnl_L.Mold 7165.JPG")
# Out:
# float32
# (1, 224, 224, 3)
# [4]
# ['Tomato__Tomato_mosaic_virus']

# %%
#convert keras model to tflite
model = tf.keras.models.load_model('model.h5')
converter =  tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
open("plant.tflite", "wb").write(tflite_model)
# Out:
# 299509472

# %%
model.save('model_cnn.h5')

# %% [markdown]
# **Dense Net**
